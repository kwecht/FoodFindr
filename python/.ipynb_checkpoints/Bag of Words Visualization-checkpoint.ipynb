# %% [markdown]
# This notebook classifies text using the bag of words method.

# %% [markdown]
# 1. Read sentence data from file
# 2. label some senteces
# 3. create bag of words features (relative frequency of each word for each label)
# 4. Train classifier to determine the sentiment of a sentence given the words in that sentence and the relative frequency of words in each labeled sentence. See application of bag-of-words using nltk here:
#     - http://stackoverflow.com/questions/10098533/implementing-bag-of-words-naive-bayes-classifier-in-nltk
#     - http://www.nltk.org/book/ch06.html
# 5. test classifier on remaining data

# %%
import pandas as pd
import numpy as np
import random
import nltk
import collections
import string
import sentiment as ss

# %% [markdown]
# ### 1. Read sentence from data

# %%
sentences = pd.read_pickle('../data/pandas/sentences_mexican_train.pkl')

# %% [markdown]
# ### 3. Create bag of words features (relative frequency of each word for each label)

# %%
bags = []
for nstar in sentences.stars.unique()[0:2]:
    print "processing stars = {}".format(nstar)
    thisdata = sentences[sentences['stars']==nstar]
    thisbag = ss.get_bag(thisdata)
    thisbag.name = str(int(nstar))
    bags.append( thisbag )
# Out:
# processing stars = 5.0
# processing stars = 1.0

# %%
dataframe = pd.concat(bags,axis=1)
total = dataframe.sum(1)
overallfreq = total / total.sum()
# Out:
#               0   1
# 'S            2 NaN
# 'berto        3 NaN
# 'd            1 NaN
# 'it         NaN   1
# 'm           24  16
# 'nough        1 NaN
# 're          31   9
# 'real         1 NaN
# 's           77  35
# 've          61  15
# **My          1 NaN
# -heck         1 NaN
# -outside      1 NaN
# -sat          1 NaN
# ...         NaN   1
# ..I         NaN   1
# ..chips       1 NaN
# ..this        1 NaN
# ..was         1 NaN
# .EVER       NaN   1
# .I            1 NaN
# .SO           1 NaN
# .a            1 NaN
# .and          1 NaN
# .but          1 NaN
# .heck         1 NaN
# .it         NaN   1
# .so           1 NaN
# .they       NaN   2
# .we           1 NaN
# ...          ..  ..
# worth        21   6
# worthy      NaN   1
# wow           2   1
# wrap          5 NaN
# wretched    NaN   1
# write         5   7
# wrong         6  10
# x3          NaN   1
# y             2 NaN
# ya            4 NaN
# yeah        NaN   2
# year         31  13
# yell        NaN   3
# yelp          1   4
# yelpers       2 NaN
# yes         NaN   3
# yesterday     1   2
# young         2   2
# younger     NaN   1
# youngest    NaN   1
# yours         1   1
# yourself..  NaN   1
# yr.         NaN   1
# yuck        NaN   1
# yum           5 NaN
# yummy         5 NaN
# yup         NaN   1
# zip         NaN   1
# ~~~         NaN   1
# ¡¡YUMAMUNDO   1 NaN
#
# [3371 rows x 2 columns]

# %%
threshold = 0.0002
tempdf = dataframe[overallfreq>threshold]

# %%
# Show words with highest/lowest ratios of 5:1 star frequency
ratio = bags['5']/bags['1']
ratio = ratio.order()
